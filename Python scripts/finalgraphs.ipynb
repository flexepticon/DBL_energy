# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
from datetime import datetime
from scipy.optimize import fsolve
from scipy.optimize import curve_fit


import os
import re
import numpy as np
import pandas as pd
from datetime import datetime
from scipy.optimize import fsolve

# Read the data from the file
file_name1 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/VAC_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
J1 = data1[:, 0]  # First column
V1 = data1[:, 1]  # Second column


plt.scatter(J1, V1, label = 'Exp 1')
plt.grid(which='both')
plt.title('Volt-Amper curve')
plt.xlabel('Current density')
plt.ylabel('Potential [V]')
plt.legend()

# %%
# Read the data from the file
file_name1 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/VAC_CORR_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
J1 = data1[:, 0]  # First column
V1 = data1[:, 1]  # Second column


plt.scatter(J1, V1, label = 'Exp 1')
plt.grid(which='both')
plt.title('Volt-Amper curve adjusted for ohmic drop')
plt.xlabel('Current density')
plt.ylabel('Potential [V]')
plt.legend()
