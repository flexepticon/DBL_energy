# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
from datetime import datetime
from scipy.optimize import fsolve
from scipy.optimize import curve_fit


import os
import re
import numpy as np
import pandas as pd
from datetime import datetime
from scipy.optimize import fsolve

# Read the data from the file
file_name1 = f'../Final Data/experiment1 6.5M KOH/VAC_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
X1 = data1[:, 0]  # First column
Y1 = data1[:, 1]  # Second column

# Read the data from the file
file_name2 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/VAC_plot.txt'  # Replace with your file name

# Use numpy to load the data
data2 = np.loadtxt(file_name2, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
X2 = data2[:, 0]  # First column
Y2 = data2[:, 1]  # Second column

plt.plot(X1, Y1, '-o',label = 'Exp 1')
plt.scatter(X2, Y2, label = 'Exp 2')
plt.grid(which='both')
plt.title('Volt-Amper curve')
plt.xlabel('Current density')
plt.ylabel('Potential [V]')
plt.legend()

# %%
# Read the data from the file
file_name1 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/VAC_CORR_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
X1 = data1[:, 0]  # First column
Y1 = data1[:, 1]  # Second column


plt.scatter(X1, Y1, label = 'Exp 1')
plt.grid(which='both')
plt.title('Volt-Amper curve adjusted for ohmic drop')
plt.xlabel('Current density')
plt.ylabel('Potential [V]')
plt.legend()

# %%
# Read the data from the file
file_name1 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/JR_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
X1 = data1[:, 0]  # First column
Y1 = data1[:, 1]  # Second column


plt.scatter(X1, Y1, label = 'Exp 1')
plt.grid(which='both')
plt.title('Ohmic resistance vs current density')
plt.xlabel('Current density')
plt.ylabel('Ohmic resistance [$\\Omega$]')
plt.legend()

# %%
# Read the data from the file
file_name1 = f'../Final Data/experiment 2 6.5M KOH 10mM LiOH/TAFEL_plot.txt'  # Replace with your file name

# Use numpy to load the data
data1 = np.loadtxt(file_name1, delimiter=';', skiprows=1)  # Skip the header row

# Separate the columns into individual arrays (optional)
X1 = data1[:, 0]  # First column
Y1 = data1[:, 1]  # Second column


plt.plot(X1, Y1)
#plt.xscale('log')
plt.grid()
plt.title('Tafel plot')
plt.xlabel('Current density')
plt.ylabel('Overpotential')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
