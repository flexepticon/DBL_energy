# %%
from ProcessingClass import Measurement
import matplotlib.pyplot as plt
import numpy as np

A = Measurement((2024, 11,22, 12,0,0), (2024, 11, 22, 14,30,0), "experiment 5- 6.mKOHplus100mM LiOH")
start_times = []
end_times = []


data = A.TRScans[:1]
ws = 10


fig, ax = plt.subplots(ncols = 2, nrows = len(data), figsize = (10, 5*len(data)))
ax = ax.flatten()
fig.suptitle('Pure KOH')
for i in range(max(1,len(data)*2-2)):
    ax[i*2].set_title('Current vs time')
    ax[i*2].plot(data[i]['time'], data[i]['I'])
    ax[i*2].grid()
    ax[i*2].set_xlabel('Time [s]')
    ax[i*2].set_ylabel('Current [A]')
    ax[i*2+1].set_title('Potential vs time')
    ax[i*2+1].plot(data[i]['time'], data[i]['V'], label = 'raw', color = 'lightgrey')
    ax[i*2+1].grid()
    ax[i*2+1].set_xlabel('Time [s]')
    ax[i*2+1].set_ylabel('Potential [V]')
    ax[i*2+1].legend()
    ax[i*2+1].set_ylim(min(data[i]['V'])/1.1, max(data[i]['V'])*1.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 5 A = Measurement((2024, 11,22, 12,0,0), (2024, 11, 22, 14,30,0), "experiment 5- 6.mKOHplus100mM LiOH")
#       6 start_times = []
#       7 end_times = []
#
# File c:\Users\egeoy\Documents\GitHub\DBL_energy\Python scripts\ProcessingClass.py:201, in Measurement.__init__(self, datetime_start, datetime_end, foldername)
#     199 # Store overpotential values and slope of log(current) vs overpotential
#     200 self.overpotential = list(self.for_computation['Overpotential'])
# --> 201 self.slope = np.polyfit(np.log10(self.for_computation['J JR']), self.for_computation['Overpotential'], 1)[0]
#     203 for plot_type in plot_types:
#     204     if plot_type == 'VAC':
#     205         # Define the file path
#
# File <__array_function__ internals>:200, in polyfit(*args, **kwargs)
#
# File c:\Users\egeoy\Documents\UNI\Ananconda\lib\site-packages\numpy\lib\polynomial.py:638, in polyfit(x, y, deg, rcond, full, w, cov)
#     636     raise TypeError("expected 1D vector for x")
#     637 if x.size == 0:
# --> 638     raise TypeError("expected non-empty vector for x")
#     639 if y.ndim < 1 or y.ndim > 2:
#     640     raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
plt.scatter(A.VAC_dataframe['J'], A.VAC_dataframe['V'], label = 'VAC')
plt.grid(which='both')
plt.title('Volt-Amper curve')
plt.xlabel('Current density')
plt.ylabel('Potential [V]')
plt.legend()

# %%
data = A.ZZplots[:2]
#data['potential_filtered'] = medfilt(data['potential'], kernel_size=11)
ws = 10


fig, ax = plt.subplots(nrows = len(data), figsize = (10, 5*len(data)))
for i in range(len(data)):
    ax[i].set_title('ZZ plot')
    ax[i].plot(data[i]['Zr'], data[i]['Zi'], label = 'Curve')
    ax[i].grid()
    ax[i].set_xlabel('$Z_R$')
    ax[i].set_ylabel('$Z_I$')
    ax[i].axvline(A.rs[i], linestyle ='--', color = 'orange', label = 'Resistance')
    ax[i].legend(loc = 'upper right')

# %%
fig, ax = plt.subplots(figsize = (10, 6))
ax.scatter(A.JR_dataframe['J'], A.JR_dataframe['R'])
ax.grid()
ax.set_title('Ohmic resistance vs current density')
ax.set_xlabel('Current density [$\\frac{A}{cm^2}$]')
ax.set_ylabel('Ohmic resistance [$\\Omega$]')
# Out:
# Text(0, 0.5, 'Ohmic resistance [$\\Omega$]')

# %%
plt.plot(A.JR_dataframe['J'], A.JR_dataframe['R'])
plt.grid()
plt.xlabel('Current density')
plt.ylabel('Averabe omic resistance')
# Out:
# Text(0, 0.5, 'Averabe omic resistance')

# %%
plt.plot(A.JR_dataframe['J'], A.overpotential, label = f'Slope = {A.slope:.2f}')
plt.xscale('log')
plt.grid()
plt.title('Tafel plot')
plt.xlabel('Current density')
plt.ylabel('Overpotential')
plt.legend()
